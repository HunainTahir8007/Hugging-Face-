# %%
import torch
from transformers import pipeline

# %%
ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
# Out:
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.weight | UNEXPECTED |  |
# bert.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]

# %%
sentence = input("Enter the text of resume \n")
# Out:
# Enter the text of resume
# "Arfa Karim from Faisalabad became the youngest Microsoft certified professional",     "Ustad Nusrat Fateh Ali Khan was born in Lyallpur now known as Faisalabad",     "Allama Iqbal was born in Sialkot and studied at Government College Lahore",     "Edhi Foundation was founded by Abdul Sattar Edhi in Karachi Pakistan",     "NUST University is located in Islamabad and is one of top universities in Pakistan"

# %%
resume_analyzer = ner(sentence)

# %%
for result in resume_analyzer:
      if result['score'] > 0.70:
        print(f"Class --> {result['entity_group']} Name --> {result['word']} with socre -->  {result['score']}")
# Out:
# Class --> PER Name --> Arfa Karim with socre -->  0.9995061755180359
# Class --> LOC Name --> Faisalabad with socre -->  0.9985076189041138
# Class --> PER Name --> Ustad Nusrat Fateh Ali Khan with socre -->  0.944472074508667
# Class --> LOC Name --> Lyallpur with socre -->  0.9960728883743286
# Class --> LOC Name --> Faisalabad with socre -->  0.9988499879837036
# Class --> PER Name --> Allama Iqbal with socre -->  0.9994806051254272
# Class --> LOC Name --> Sialkot with socre -->  0.997525691986084
# Class --> LOC Name --> Lahore with socre -->  0.990264892578125
# Class --> ORG Name --> Edhi Foundation with socre -->  0.973850667476654
# Class --> PER Name --> Abdul Sattar Edhi with socre -->  0.9974050521850586
# Class --> LOC Name --> Karachi Pakistan with socre -->  0.999017596244812
# Class --> ORG Name --> NUST University with socre -->  0.9927052855491638
# Class --> LOC Name --> Islamabad with socre -->  0.9994008541107178
# Class --> LOC Name --> Pakistan with socre -->  0.9990602135658264
