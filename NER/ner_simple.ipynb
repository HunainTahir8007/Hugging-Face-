# %%
from transformers import pipeline
import torch

# %%
ner = pipeline("ner", )
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.weight | UNEXPECTED |  |
# bert.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
txt = "Elon Musk founded Tesla in California"
res= ner(txt)
res
# Out:
# [{'entity': 'I-PER',
#   'score': np.float32(0.9993192),
#   'index': 1,
#   'word': 'El',
#   'start': 0,
#   'end': 2},
#  {'entity': 'I-PER',
#   'score': np.float32(0.9985864),
#   'index': 2,
#   'word': '##on',
#   'start': 2,
#   'end': 4},
#  {'entity': 'I-PER',
#   'score': np.float32(0.9987424),
#   'index': 3,
#   'word': 'Mu',
#   'start': 5,
#   'end': 7},
#  {'entity': 'I-PER',
#   'score': np.float32(0.992265),
#   'index': 4,
#   'word': '##sk',
#   'start': 7,
#   'end': 9},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.9567225),
#   'index': 6,
#   'word': 'Te',
#   'start': 18,
#   'end': 20},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.8745628),
#   'index': 7,
#   'word': '##sla',
#   'start': 20,
#   'end': 23},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.9996884),
#   'index': 9,
#   'word': 'California',
#   'start': 27,
#   'end': 37}]

# %%
# ner with agrigation
neer = pipeline("ner" , aggregation_strategy="simple")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.weight | UNEXPECTED |  |
# bert.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'entity_group': 'PER',
#   'score': np.float32(0.99722826),
#   'word': 'Elon Musk',
#   'start': 0,
#   'end': 9},
#  {'entity_group': 'ORG',
#   'score': np.float32(0.9156426),
#   'word': 'Tesla',
#   'start': 18,
#   'end': 23},
#  {'entity_group': 'LOC',
#   'score': np.float32(0.9996884),
#   'word': 'California',
#   'start': 27,
#   'end': 37}]

# %%
neer(txt)
# Out:
# [{'entity_group': 'PER',
#   'score': np.float32(0.99722826),
#   'word': 'Elon Musk',
#   'start': 0,
#   'end': 9},
#  {'entity_group': 'ORG',
#   'score': np.float32(0.9156426),
#   'word': 'Tesla',
#   'start': 18,
#   'end': 23},
#  {'entity_group': 'LOC',
#   'score': np.float32(0.9996884),
#   'word': 'California',
#   'start': 27,
#   'end': 37}]

# %%
sentences = [
    "Elon Musk founded Tesla in California",
    "Bill Gates created Microsoft in Seattle in 1975",
    "Imran Khan was born in Lahore Pakistan",
    "Mark Zuckerberg built Facebook at Harvard University",
    "Apple was founded by Steve Jobs in Cupertino",
    "Cristiano Ronaldo plays for Al Nassr in Saudi Arabia",
    "Ahmed Khan studied at FAST University in Lahore"]

# %%
for i in sentences:
  res = neer(i)
  for entity in res:
    print(f"{entity["word"]} -----> {entity["entity_group"]}")
# Out:
# Elon Musk -----> PER
# Tesla -----> ORG
# California -----> LOC
# Bill Gates -----> PER
# Microsoft -----> ORG
# Seattle -----> LOC
# Imran Khan -----> PER
# Lahore Pakistan -----> LOC
# Mark Zuckerberg -----> PER
# Facebook -----> ORG
# Harvard University -----> ORG
# Apple -----> ORG
# Steve Jobs -----> PER
# Cupertino -----> LOC
# Cristiano Ronaldo -----> PER
# Al Nassr -----> ORG
# Saudi Arabia -----> LOC
# Ahmed Khan -----> PER
# FAST University -----> ORG
# Lahore -----> LOC
